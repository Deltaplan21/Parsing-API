# %%
import pandas as pd

# %%
df = pd.read_csv('job.csv')
df
# Out:
#                                                   name  \
# 0                                    Lead data science
# 1                                         Data Manager
# 2                                         Data science
# 3                                Python Data Scientist
# 4                              Quantitative Researcher
# 5    Руководитель направления по исследованию данны...
# 6                                 Head of Data Science
# 7    Экономист-математик (IO, эконометрика/data sci...
# 8                                       Data scientist
# 9                               Data Science (gamedev)
# 10                                      Data Scientist
# 11                   Аналитик в финансовый департамент
# 12                                      Data Scientist
# 13                                      Data Scientist
# 14          Руководитель по аналитике (Data Scientist)
# 15                               Data Science Engineer
# ...

# %%
df.loc[:,['salary_min','salary_max']].astype('int')
# Out:
#      salary_min  salary_max
# 0        200000      250000
# 1             0           0
# 2        200000           0
# 3        150000           0
# 4        300000           0
# 5             0           0
# 6             0           0
# 7         60000      130000
# 8             0           0
# 9             0           0
# 10            0           0
# 11       120000           0
# 12            0           0
# 13       150000           0
# 14            0           0
# 15        50000           0
# 16       250000      250000
# 17            0           0
# 18            0      130000
# 19            0           0
# 20            0           0
# 21            0           0
# 22            0           0
# 23            0           0
# 24            0           0
# 25            0           0
# 26            0           0
# 27            0           0
# 28            0           0
# 29            0           0
# ..          ...         ...
# 161       40000       60000
# ...

# %%
df.dtypes
# Out:
# name          object
# company       object
# salary_min     int64
# salary_max     int64
# link          object
# site          object
# dtype: object

# %%
df.to_csv('jobs.csv', index=None)
