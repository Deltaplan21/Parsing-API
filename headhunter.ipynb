# %%
import pandas as pd

# %%
pd.read_csv('hh.csv')
# Out:
#      Unnamed: 0                                               name  \
# 0             0                                       Data science
# 1             1                   Руководитель отдела data science
# 2             2                                       Data Analyst
# 3             3                                     Data scientist
# 4             4                               Head of Data Science
# 5             5  Экономист-математик (IO, эконометрика/data sci...
# 6             6                  Аналитик в финансовый департамент
# 7             7                                     Data Scientist
# 8             8  Разработчик корпоративной аналитики и отчетнос...
# 9             9                              Data Science Engineer
# 10           10                     Junior Quantitative Researcher
# 11           11                 Стажёр(Анализ данных,data science)
# 12           12                               Head of Data Science
# ...
